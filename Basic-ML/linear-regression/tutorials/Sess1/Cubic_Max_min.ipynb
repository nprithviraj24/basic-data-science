# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-3,3,.001)
print(x)

v = 10**2
v
# Out:
# [-3.    -2.999 -2.998 ...  2.997  2.998  2.999]
# 100

# %%
def function_a(var):
    polynomial = 2*var**3 - 3*var**2 - 12*x +12
    return polynomial

# %%
f_x = function_a(x)

# %%
fig = plt.figure()
ax = plt.axes()
# plt.grid(axis='both')
plt.plot(x,f_x,'-')
plt.show()

# %%
def f_x_der(x):
    return 6*x**2 - 6*x - 12

# %%
first_der = f_x_der(x)
fig = plt.figure()
ax = plt.axes()
plt.grid(axis='both')
plt.plot(x,f_x,'b-')
plt.plot(x, first_der, 'c--')
plt.show()

# %% [markdown]
# ### What is happening after this????

# %%
def f_x_roots(x):
    roots = []
    #print(type(roots))
    for i in x:
        if (abs(f_x_der(i)) < .000001):           
            roots.append(i)
    return roots

# %%
roots_array = f_x_roots(x)

# %%
print(roots_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cb82f0faab83> in <module>
# ----> 1 print(roots_array)
#
# NameError: name 'roots_array' is not defined
