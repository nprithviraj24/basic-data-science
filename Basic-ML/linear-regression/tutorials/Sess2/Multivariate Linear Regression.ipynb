# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Datatypes in Pandas:
# ## Series, DataFrame and 3rd one.

# %%
data = pd.read_csv("Housing_data.txt", header=None, names=['House_size', 'NoofBedroom', 'Price'])
# print(data.head)
# type(data)

# %% [markdown]
# ### Read_csv()
# - Path
# - Header = none
# - Column names
#
# ### describe()
# - Count: number of values in particular column.
# - Mean, std, min and max
#
# If a data has mean and standard deviation, it is said to have a Guassian distribution.

# %%
data.describe()
# Out:
#         House_size  NoofBedroom          Price
# count    47.000000    47.000000      47.000000
# mean   2000.680851     3.170213  340412.659574
# std     794.702354     0.760982  125039.899586
# min     852.000000     1.000000  169900.000000
# 25%    1432.000000     3.000000  249900.000000
# 50%    1888.000000     3.000000  299900.000000
# 75%    2269.000000     4.000000  384450.000000
# max    4478.000000     5.000000  699900.000000

# %% [markdown]
# ### Standardize the data
# - Making the mean 0
# - Std: 1

# %%
fig, ax = plt.subplots(1,3)
# Rows and columns in subplots
fig.set_figwidth(5)
fig.set_figwidth(20)

plt1 = plt.subplot(1,3,1) # Number of rows, Number of columns, Select it's position.
plt2 = plt.subplot(1,3,2)
plt3 = plt.subplot(1,3,3)


plt1.hist(data['House_size'], label='House Size', edgecolor='black')
plt1.set_title('House Size')
plt1.set_xlabel('Size')
plt1.set_ylabel('Frequency')
plt1.grid(axis='both', alpha=.25)



#This has almost perfect Guassian Distribution
plt2.hist(data['NoofBedroom'], label='Bedrooms', edgecolor='black')
plt2.set_title('Number of Bedrooms')
plt2.set_xlabel('Bedrooms')
plt2.set_ylabel('Frequency')
plt2.grid(axis='both', alpha=.25)



plt3.hist(data['Price'], label='Price', edgecolor='black')
plt3.set_title('Price Ranges')
plt3.set_xlabel('Price')
plt3.set_ylabel('Frequency')
plt3.grid(axis='both', alpha=.25)

# %% [markdown]
# ## Types of Regression:
# All these are Linear Regression
#
# ##### Simple
# y = a<sub>0</sub> + a<sub>1</sub>x
#
# ##### Multiple Variable
# y = a<sub>0</sub>+ a<sub>1</sub>x<sub>1</sub> + a<sub>2</sub>x<sub>2</sub> + .... a<sub>n</sub>x<sub>n</sub>
#
# ##### Polynomial
# y = a<sub>0</sub>+ a<sub>1</sub>x<sup>1</sup> + a<sub>2</sub>x<sup>2</sup> + .... a<sub>n</sub>x<sup>n</sup>

# %%
data = pd.read_csv("Housing_data.txt", header=None, names=['x1', 'x2', 'y'])
# print(data.head)
# type(data)

# %%
def h(x,theta):
    return np.dot(x,theta)

# %% [markdown]
# A<sup>T</sup>.A = A<sup>2</sup>

# %%
def cost(theta, x):
    return (1/2)*(h(X,theta)-y).T.dot(h(X,theta) - y)
# data.shape
# Out:
# (47, 3)

# %% [markdown]
# ### Numpy operations:
#
# size = data.shape
#
# ##### Omit last column from an nd array:
#     mat.column[0:size[1]-1]
#
# ##### Properties:
# - x.values is property  of Pandas.

# %%
x = data[data.columns[0:data.shape[1]-1]]
y = data['y']
# print(x.values)
x = x.values
X = np.insert(x,0,1, axis=1)
print(X)
# Out:
# [[   1 2104    3]
#  [   1 1600    3]
#  [   1 2400    3]
#  [   1 1416    2]
#  [   1 3000    4]
#  [   1 1985    4]
#  [   1 1534    3]
#  [   1 1427    3]
#  [   1 1380    3]
#  [   1 1494    3]
#  [   1 1940    4]
#  [   1 2000    3]
#  [   1 1890    3]
#  [   1 4478    5]
#  [   1 1268    3]
#  [   1 2300    4]
#  [   1 1320    2]
#  [   1 1236    3]
#  [   1 2609    4]
#  [   1 3031    4]
#  [   1 1767    3]
#  [   1 1888    2]
#  [   1 1604    3]
#  [   1 1962    4]
#  [   1 3890    3]
#  [   1 1100    3]
#  [   1 1458    3]
#  [   1 2526    3]
#  [   1 2200    3]
#  [   1 2637    3]
#  [   1 1839    2]
#  [   1 1000    1]
#  [   1 2040    4]
#  [   1 3137    3]
#  [   1 1811    4]
#  [   1 1437    3]
#  [   1 1239    3]
#  [   1 2132    4]
#  [   1 4215    4]
#  [   1 2162    4]
#  [   1 1664    2]
#  [   1 2238    3]
#  [   1 2567    4]
#  [   1 1200    3]
#  [   1  852    2]
#  [   1 1852    4]
#  [   1 1203    3]]

# %%
val1 = np.linalg.inv(np.dot(np.transpose(X),X))
val2 = np.dot(np.transpose(X),y)
theta_optimal = np.dot(val1, val2)
theta_optimal
# Out:
# array([89597.9095428 ,   139.21067402, -8738.01911233])

# %% [markdown]
# ### Normalising the data

# %%
data_norm = (data-data.mean())/data.std()
data_norm
# Out:
#           x1        x2         y
# 0   0.130010 -0.223675  0.475747
# 1  -0.504190 -0.223675 -0.084074
# 2   0.502476 -0.223675  0.228626
# 3  -0.735723 -1.537767 -0.867025
# 4   1.257476  1.090417  1.595389
# 5  -0.019732  1.090417 -0.323998
# 6  -0.587240 -0.223675 -0.204036
# 7  -0.721881 -0.223675 -1.130948
# 8  -0.781023 -0.223675 -1.026973
# 9  -0.637573 -0.223675 -0.783051
# 10 -0.076357  1.090417 -0.803053
# 11 -0.000857 -0.223675  0.052682
# 12 -0.139273 -0.223675 -0.083283
# 13  3.117292  2.404508  2.874981
# 14 -0.921956 -0.223675 -0.643896
# 15  0.376643  1.090417  0.875619
# 16 -0.856523 -1.537767 -0.323998
# 17 -0.962223 -0.223675 -1.123743
# 18  0.765468  1.090417  1.276275
# 19  1.296484  1.090417  2.068039
# 20 -0.294048 -0.223675 -0.699878
# 21 -0.141790 -1.537767 -0.683083
# 22 -0.499157 -0.223675 -0.779852
# 23 -0.048673  1.090417 -0.643896
# 24  2.377392 -0.223675  1.867303
# 25 -1.133356 -0.223675 -0.723870
# 26 -0.682873 -0.223675  0.992382
# ...
